# %% [markdown]
# # Polynomial Regeression

# %% [markdown]
# # importing the libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# # traning the linear Regeression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# # training the polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree =4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# # visualising the linear Regression results

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X), color = 'blue')
plt.title('truth or bluff (linear regeression)')
plt.xlabel('position level')
plt.ylabel('salary')
plt.show()

# %% [markdown]
# # visulising the polynomial Regression results

# %%
plt.scatter(X, y, color ='red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('truth or buffer(Polynomial Regression)')
plt.xlabel('position lebel')
plt.ylabel('salary')
plt.show()

# %% [markdown]
# # visualising the polynomial regression result (for higer resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X, y, color= 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('truth or buffer (Polynomial Regression ')
plt.xlabel('position level')
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_9240\3323183460.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# # predicting a new result with linear regeression

# %%
lin_reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# # predicting a new result with polynomial Regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.4526515])
